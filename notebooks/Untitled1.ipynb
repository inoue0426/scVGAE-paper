# %%
import numpy as np
# ^^^ pyforest auto-imports - don't write above this line
import pandas as pd

# %%
df = pd.read_csv('../data/hrvatin/hrvatin_genes.csv', index_col=0)
df
# Out:
#                     0610007P14Rik  0610009B22Rik  0610009E02Rik  \
# x2_35_0_bc0014                  0              1              0
# x2_35_0_bc0038                  0              0              0
# x2_35_0_bc0039                  0              0              0
# x2_35_0_bc0040                  0              0              0
# x2_35_0_bc0052                  0              0              0
# ...                           ...            ...            ...
# x2_98_4_2_2_bc2519              0              0              0
# x2_98_4_2_2_bc2550              1              0              0
# x2_98_4_2_2_bc2602              0              0              0
# x2_98_4_2_2_bc2662              0              0              0
# x2_98_4_2_2_bc2769              0              0              0
#
#                     0610009L18Rik  0610009O20Rik  0610010F05Rik  \
# x2_35_0_bc0014                  0              1              3
# x2_35_0_bc0038                  0              0              0
# ...

# %%
df.index = np.load('../data/hrvatin/hrvatin_celltype.npy')
# Out:
# array(['ExcL5_3', 'ExcL4', 'ExcL4', ..., 'Micro_2', 'Olig_4', 'Endo_1'],
#       dtype='<U10')

# %%
df
# Out:
#           0610007P14Rik  0610009B22Rik  0610009E02Rik  0610009L18Rik  \
# ExcL5_3               0              1              0              0
# ExcL4                 0              0              0              0
# ExcL4                 0              0              0              0
# ExcL5_1               0              0              0              0
# ExcL5_3               0              0              0              0
# ...                 ...            ...            ...            ...
# OPC_1                 0              0              0              0
# Pericyte              1              0              0              0
# Micro_2               0              0              0              0
# Olig_4                0              0              0              0
# Endo_1                0              0              0              0
#
#           0610009O20Rik  0610010F05Rik  0610010K14Rik  0610011F06Rik  \
# ...

# %%
df.to_csv('../data/hrvatin/data.csv.gz', compression='gzip')
